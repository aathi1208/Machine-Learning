# %% [markdown]
# <a href="https://colab.research.google.com/github/aathi1208/Machine-Learning/blob/main/CATBOOST-Amazon%20employee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df_test=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/amazon-employee-access-challenge/test.csv")
df_test
# Out:
#           id  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0          1     78766   72734         118079         118080         117878
# 1          2     40644    4378         117961         118327         118507
# 2          3     75443    2395         117961         118300         119488
# 3          4     43219   19986         117961         118225         118403
# 4          5     42093   50015         117961         118343         119598
# ...      ...       ...     ...            ...            ...            ...
# 58916  58917     75078    4565         117961         118386         121961
# 58917  58918      6977   72209         117961         118225         124948
# 58918  58919     39262    6114         117961         118343           6104
# 58919  58920      1023    8674         117961         118327         120318
# 58920  58921     44977    3918         117961         118343         118660
#
# ...

# %%
df_train=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/amazon-employee-access-challenge/train.csv")
df_train
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     39353   85475         117961         118300         123472
# 1           1     17183    1540         117961         118343         123125
# 2           1     36724   14457         118219         118220         117884
# 3           1     36135    5396         117961         118343         119993
# 4           1     42680    5905         117929         117930         119569
# ...       ...       ...     ...            ...            ...            ...
# 32764       1     23497   16971         117961         118300         119993
# 32765       1     25139  311198          91261         118026         122392
# 32766       1     34924   28805         117961         118327         120299
# 32767       1     80574   55643         118256         118257         117945
# 32768       1     14354   59575         117916         118150         117920
#
# ...

# %%
df_train["ACTION"].value_counts() # we can use as y_train
# Out:
# ACTION
# 1    30872
# 0     1897
# Name: count, dtype: int64

# %%
df_test.isnull().sum()
# Out:
# id                  0
# RESOURCE            0
# MGR_ID              0
# ROLE_ROLLUP_1       0
# ROLE_ROLLUP_2       0
# ROLE_DEPTNAME       0
# ROLE_TITLE          0
# ROLE_FAMILY_DESC    0
# ROLE_FAMILY         0
# ROLE_CODE           0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# ACTION              0
# RESOURCE            0
# MGR_ID              0
# ROLE_ROLLUP_1       0
# ROLE_ROLLUP_2       0
# ROLE_DEPTNAME       0
# ROLE_TITLE          0
# ROLE_FAMILY_DESC    0
# ROLE_FAMILY         0
# ROLE_CODE           0
# dtype: int64

# %%
X_train=df_train['ACTION']

# %%
df_train.drop(labels="ACTION",axis=1,inplace=True)

# %%
X_test=df_train

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X_test, X_train, test_size=0.2, random_state=0)

# %%
# !pip install catboost
from catboost import CatBoostClassifier
model = CatBoostClassifier(iterations=500, depth=10, learning_rate=0.05, loss_function='Logloss')
model.fit(X_test, X_train)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 6.9 MB/s eta 0:00:00
# ...
# 0:	learn: 0.6323419	total: 89.5ms	remaining: 44.7s
# 1:	learn: 0.5773534	total: 124ms	remaining: 30.9s
# 2:	learn: 0.5309032	total: 157ms	remaining: 26.1s
# 3:	learn: 0.4904558	total: 193ms	remaining: 23.9s
# 4:	learn: 0.4552108	total: 226ms	remaining: 22.3s
# 5:	learn: 0.4218329	total: 261ms	remaining: 21.5s
# 6:	learn: 0.3952533	total: 299ms	remaining: 21.1s
# 7:	learn: 0.3716087	total: 334ms	remaining: 20.5s
# 8:	learn: 0.3513933	total: 367ms	remaining: 20s
# 9:	learn: 0.3339763	total: 401ms	remaining: 19.7s
# 10:	learn: 0.3189056	total: 436ms	remaining: 19.4s
# 11:	learn: 0.3045445	total: 467ms	remaining: 19s
# 12:	learn: 0.2931282	total: 501ms	remaining: 18.8s
# 13:	learn: 0.2813877	total: 543ms	remaining: 18.8s
# 14:	learn: 0.2719436	total: 589ms	remaining: 19.1s
# 15:	learn: 0.2638558	total: 624ms	remaining: 18.9s
# 16:	learn: 0.2555199	total: 656ms	remaining: 18.6s
# ...

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
accuracy = accuracy_score(X_train, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9675302877719796
